# %%
#

Link_sam = "https://github.com/facebookresearch/segment-anything"
# Out:
#   File "<ipython-input-1-9fd516f74c4e>", line 1
#     https://github.com/facebookresearch/segment-anything
#           ^
# SyntaxError: invalid syntax

# %%
# !git clone

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# SAM Generating mask

# %%
# !pip install git+https://github.com/facebookresearch/segment-anything.git
# Out:
# Collecting git+https://github.com/facebookresearch/segment-anything.git
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-4nu452wy
#   Running command git clone --filter=blob:none --quiet https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-4nu452wy
#   Resolved https://github.com/facebookresearch/segment-anything.git to commit dca509fe793f601edb92606367a655c15ac00fdf
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: segment_anything
#   Building wheel for segment_anything (setup.py) ... done
#   Created wheel for segment_anything: filename=segment_anything-1.0-py3-none-any.whl size=36592 sha256=b2e87fc50dd2bb177a0757d3cc01f404cdc4276bf5a424f4ae49901dc65e6da5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-w37mpo66/wheels/10/cf/59/9ccb2f0a1bcc81d4fbd0e501680b5d088d690c6cfbc02dc99d
# Successfully built segment_anything
# Installing collected packages: segment_anything
# Successfully installed segment_anything-1.0

# %%
# !git clone git@github.com:facebookresearch/segment-anything.git
# !cd segment-anything; pip install -e .
# Out:
# Cloning into 'segment-anything'...
# Host key verification failed.
# fatal: Could not read from remote repository.
#
# Please make sure you have the correct access rights
# and the repository exists.
# /bin/bash: line 1: cd: segment-anything: No such file or directory
# Obtaining file:///content
# ERROR: file:///content does not appear to be a Python project: neither 'setup.py' nor 'pyproject.toml' found.
